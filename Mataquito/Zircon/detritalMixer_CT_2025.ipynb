# %% [markdown]
# # DetritalPy Mixing code for the Mataquito River Every Scenario

# %% [markdown]
# ## detritalPy-mix
# #### Glenn R. Sharman and Sam A. Johnstone
# #### Code for conducting 'top-down', or forward, mixture modeling of detrital zircon U-Pb ages that incorporates a bootstrapping-derived estimate of uncertainty
# #### Version 0.1 (Beta)
# ##### Updated Feb 9, 2024
# ##### Requires detritalPy v1.4.0 or later
# ##### This is a Beta release detritalPy-mix. Please contact Glenn Sharman (gsharman@uark.edu) if you encounter any errors or problems.
# ##### If you find this code helpful in your research, please consider citing Malkowski et al. (2019): American Journal of Science (https://doi.org/10.2475/10.2019.02) and/or Sharman and Johnstone (2017): Earth and Planetary Science Letters (https://doi.org/10.1016/j.epsl.2017.07.044)

# %% [markdown]
# ### The first scenario will be run with the orginal struture from detritalpy-mix followed by more condensed versions for alternative mixture results

# %% [markdown]
# ### I. Import required modules
# This step must by run initially, but then does not need to be run again for the remainder of the analysis session.
# <i>Hint: select a cell with code and Shift+Enter to execute it</i>

# %%
import detritalpy
from detritalpy import detritalFuncs as dFunc
from detritalpy import detritalMixer as dMix
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # For improving matplotlib figure resolution
matplotlib.rcParams['pdf.fonttype'] = 42 # For allowing preservation of fonts upon importing into Adobe Illustrator
matplotlib.rcParams['ps.fonttype'] = 42
print('detritalPy version: ',detritalpy.__version__)
# Out:
# detritalPy version:  1.4.3

# %% [markdown]
# ### II. Import the dataset as an Excel file
# This step must by run initially, and should be repeated if any changes are made to the dataset in Excel. The simplest way to load data is to place the Excel file(s) in the same directory or a sub-directory of the Jupyter Notebook file. For more options, please refer to dataLoading.ipynb.

# %% [markdown]
# Parent samples are those that will be mixed together. Child samples are the samples that are assumed to be mixtures of the parents. Individual samples or groups of samples can be selected by entering their unique Sample ID's in an array or tuple (see examples below for the correct syntax).
#
# Change parent and child list to see mixing results for CT-1 through CT-11

# %%
dataToLoad = ['/Users/Glong1/Desktop/Andes/AndesTG/Mataquito/Zircon/Spreadsheets/CT-1-11_ZrUPb_datasheets.xlsx']
main_df, main_byid_df, samples_df, analyses_df = dFunc.loadDataExcel(dataToLoad, dataSheet='ZrUPb')

""" 
Plug in the two / three parents that you want followed by all the children associated with all the parents.
"""
#parent_list = ['CT-7', 'CT-1']
#child_list = ['CT-4']

#parent_list = ['CT-7', 'CT-1']
#child_list = ['CT-10']

#parent_list = ['CT-7', 'CT-1']
#child_list = ['CT-11']

#parent_list = ['CT-7', 'CT-1']
#child_list = ['CT-8.2']

#parent_list = ['CT-7', 'CT-1']
#child_list = ['CT-2']

#parent_list = ['CT-7', 'CT-1']
#child_list = ['CT-9']

parent_list = ['CT-5', 'CT-6']
child_list = ['CT-4']

#parent_list = ['CT-5', 'CT-6']
#child_list = ['CT-10']

#parent_list = ['CT-5', 'CT-6']
#child_list = ['CT-11']

#parent_list = ['CT-5', 'CT-6']
#child_list = ['CT-8.2']

#parent_list = ['CT-5', 'CT-6']
#child_list = ['CT-2']

#parent_list = ['CT-5', 'CT-6']
#child_list = ['CT-9']

#parent_list = ['CT-4', 'CT-3']
#child_list = ['CT-2']

#parent_list = ['CT-10', 'CT-3']
#child_list = ['CT-2']

#parent_list = ['CT-11', 'CT-3']
#child_list = ['CT-2']

#parent_list = ['CT-8.2', 'CT-3']
#child_list = ['CT-2']

#parent_list = ['CT-4', 'CT-3']
#child_list = ['CT-9']

#parent_list = ['CT-10', 'CT-3']
#child_list = ['CT-9']

#parent_list = ['CT-11', 'CT-3']
#child_list = ['CT-9']

#parent_list = ['CT-8.2', 'CT-3']
#child_list = ['CT-9']

#parent_list = ['CT-2', 'CT-3']
#child_list = ['CT-9']

#parent_list = ['CT-5', 'CT-6', 'CT-3']
#child_list = ['CT-2']

#parent_list = ['CT-1', 'CT-7', 'CT-3']
#child_list = ['CT-2']

#parent_list = ['CT-1', 'CT-7', 'CT-3']
#child_list = ['CT-9']

#parent_list = ['CT-5', 'CT-6', 'CT-3']
#child_list = ['CT-9']

# %% [markdown]
# ### Calculate best-fit mixture

# %% [markdown]
# **Selecting your definition for 'best-fit'**
#
# detritalPy-mix provides a few options for assessing (and minimizing) the difference between observed and modelled distributions. We refer to these functions as 'objective_metric', you can select from the different values printed below. We suggest reviewing Saylor and Sundell (2016): Geosphere (doi:10.1130/GES01237.1) for an overview of these metrics. Note that the 'ss' option is the square root of the sum of squared residuals bewteen the two empirical CDFs (i.e., L2 norm).

# %%
print('Options for objective_metric available in detritalPy-Mix:')
print(dMix.AVAILABLE_METRICS)
# Out:
# Options for objective_metric available in detritalPy-Mix:
# ['dmax', 'vmax', 'similarity-pdp', 'likeness-pdp', 'r2-pdp', 'similarity-kde', 'likeness-kde', 'r2-kde', 'ss']

# %% [markdown]
# The options below specify how the mixture modeling will be conducted. Please choose these parameters carefully, as the result will depend on the objective metric chosen and the choice of KDE parameters (bandwidth), if using one of the KDE-based objective metrics (e.g., r2-kde).

# %%
# What is the comparison metric to use, could be 'dmax','vmax', 'ss', 'r2-pdp','likeness-pdp', 'similarity-pdp', 'r2-kde','likeness-kde', 'similarity-kde', or 'L1norm'
objective_metric = 'vmax' # This determines if a PDF of a CDF is used to mix and compare data

# Specify the age range (Myr) over which you want to conduct mixture modeling
x1 = 0 # Strongly recommended value of 0 Ma
x2 = 4500 # Strongly recommended value of 4500 Ma

# If using a KDE-based objective metric (e.g., 'r2-kde'), the mixture modeling results will depend on choice of bandwidth
bw = 2 # Bandwidth of gaussian KDE in Myr (only used if a KDE is constructed to apply the chosen comparison metric)
bw_x = None # X-axis location of bandwidth split (only used if multiple KDE values are specified). Set to None if not using a split bandwidth.

# Specify the interval (Myr) over which distributions are calculated
xdif = 1 # Note: an interval of 1 Myr is recommended 


mix_coeffs_bf, obj_func_val, best_mixed_dist = dMix.find_best_fit_mix(parent_list, child_list, main_byid_df, sigma='1sigma', objective_metric=objective_metric,
                      x1=x1, x2=x2, xdif=xdif, bw=bw, bw_x=bw_x, verbose=True)
# Out:
# Starting: CT-4
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.051611751021951174
#             Iterations: 9
#             Function evaluations: 39
#             Gradient evaluations: 9
# Completed mixing children.
# Time elapsed: 0.059 seconds

# %% [markdown]
# Optional: Running the code below will list the best-fit mixture of each of the sources for each child sample

# %%
dMix.print_best_fit_mixture(parent_list, child_list, objective_metric, obj_func_val, mix_coeffs_bf)
# Out:
# Sample: CT-4
# Best-fit vmax : 0.052
# Mixing coefficients
# --- CT-5 : 0.272
# --- CT-6 : 0.728

# %%
# Eliminate the values where the mixing coefficients are either 0 or 1, since that is impossible

# %% [markdown]
# <b>Recommended exercise: </b> Try a different objective_metric option to see if you get a different result.

# %% [markdown]
# ### Construct many bootstrapped estimates of mixing coefficients
# Rather than rely on a single best-fit mixture, bootstrapping allows for an estimate of uncertainty in the mixing prediction. Bootstrapping is accomplished by calculating the best-fit mixture multiple times, after resampling with replacement both parent and child sample(s).

# %% [markdown]
# <b>Note:</b> 100 iterations takes about a minute. Use fewer boostrapps for testing, and then when you are ready, perform a large number (e.g., 5000) and let it run overnight

# %%
# How many bootstrap iterations should we preform. In practice 1000s is a good idea, but use fewer
# during testing to speed things up
nBootstrapIterations = 5000

# Do we want to only resample with replacement? Or should original observed ages additionally be redrawn
# based on the observed error
doPerturbResampledAges = False

# Do we want to construct bootstrapped estimates by drawing a specific number of grains from each sample?
# If None, defaults to the observed number of grains
nGrainsToResample = None

# Uncertainly level of input data (options: '1sigma' or '2sigma')
sigma = '2sigma' 

# Perform bootstrapped mixture modelling for each of the samples
mix_coeffs_all, obj_vals_all, child_modelled_distributions = dMix.bootstrap_solve_mixture_models(parent_list,
                                                                           child_list,main_byid_df,
                                                                            sigma = sigma,
                                                                            objective_metric = objective_metric,
                                                                            nBootstrapIterations = nBootstrapIterations, 
                                                                            doPerturbResampledAges = doPerturbResampledAges,
                                                                            nGrainsToResample = nGrainsToResample,
                                                                            x1=x1, x2=x2, xdif=xdif,bw = bw, bw_x = bw_x,
                                                                                                verbose = True, update_freq = 10)

# Create a bootstrapped distribution of the children as well
selfCompMetrics_bs_set, childDists_bs_set = dMix.bootstrapped_self_comparisons_many_samples(main_byid_df,child_list,
                                                                                            doPerturbResampledAges = doPerturbResampledAges,
                                                                                            objective_metric = objective_metric,sigma = sigma,
                                                                                            x1 = x1, x2 = x2,xdif = xdif, bw = bw, bw_x = bw_x,
                                                                                            nBootstrapIterations = nBootstrapIterations)

# Calculate whether the best-fit mixture is a 'good' mixture by comparing the best-fit metric
# with the 5% poorest objective functions from resampling the child
obj_func_crit, worse_than_crit = dMix.calc_model_fit(child_list, obj_func_val, obj_vals_all, selfCompMetrics_bs_set, objective_metric=objective_metric)
# Out:
# -----------------------------------------------------------------
# Starting : CT-4 ( 1 of 1 child samples)
# 0.0 % completed, 0.001 minutes elapsed, 5.146 minutes remaining
# 0.2 % completed, 0.006 minutes elapsed, 2.741 minutes remaining
# 0.4 % completed, 0.011 minutes elapsed, 2.613 minutes remaining
# 0.6 % completed, 0.016 minutes elapsed, 2.577 minutes remaining
# 0.8 % completed, 0.021 minutes elapsed, 2.552 minutes remaining
# 1.0 % completed, 0.026 minutes elapsed, 2.535 minutes remaining
# 1.2 % completed, 0.031 minutes elapsed, 2.524 minutes remaining
# 1.4 % completed, 0.036 minutes elapsed, 2.51 minutes remaining
# 1.6 % completed, 0.041 minutes elapsed, 2.497 minutes remaining
# 1.8 % completed, 0.046 minutes elapsed, 2.491 minutes remaining
# 2.0 % completed, 0.051 minutes elapsed, 2.487 minutes remaining
# 2.2 % completed, 0.056 minutes elapsed, 2.479 minutes remaining
# 2.4 % completed, 0.061 minutes elapsed, 2.469 minutes remaining
# 2.6 % completed, 0.066 minutes elapsed, 2.46 minutes remaining
# 2.8 % completed, 0.071 minutes elapsed, 2.454 minutes remaining
# 3.0 % completed, 0.076 minutes elapsed, 2.446 minutes remaining
# 3.2 % completed, 0.081 minutes elapsed, 2.439 minutes remaining
# 3.4 % completed, 0.086 minutes elapsed, 2.434 minutes remaining
# 3.6 % completed, 0.091 minutes elapsed, 2.426 minutes remaining
# 3.8 % completed, 0.096 minutes elapsed, 2.42 minutes remaining
# 4.0 % completed, 0.101 minutes elapsed, 2.414 minutes remaining
# 4.2 % completed, 0.106 minutes elapsed, 2.407 minutes remaining
# 4.4 % completed, 0.111 minutes elapsed, 2.4 minutes remaining
# 4.6 % completed, 0.116 minutes elapsed, 2.395 minutes remaining
# 4.8 % completed, 0.121 minutes elapsed, 2.39 minutes remaining
# 5.0 % completed, 0.126 minutes elapsed, 2.384 minutes remaining
# 5.2 % completed, 0.131 minutes elapsed, 2.378 minutes remaining
# 5.4 % completed, 0.136 minutes elapsed, 2.372 minutes remaining
# 5.6 % completed, 0.141 minutes elapsed, 2.367 minutes remaining
# 5.8 % completed, 0.146 minutes elapsed, 2.362 minutes remaining
# 6.0 % completed, 0.151 minutes elapsed, 2.358 minutes remaining
# 6.2 % completed, 0.156 minutes elapsed, 2.352 minutes remaining
# 6.4 % completed, 0.161 minutes elapsed, 2.347 minutes remaining
# 6.6 % completed, 0.166 minutes elapsed, 2.342 minutes remaining
# 6.8 % completed, 0.171 minutes elapsed, 2.337 minutes remaining
# 7.0 % completed, 0.176 minutes elapsed, 2.332 minutes remaining
# 7.2 % completed, 0.181 minutes elapsed, 2.326 minutes remaining
# 7.4 % completed, 0.186 minutes elapsed, 2.321 minutes remaining
# 7.6 % completed, 0.191 minutes elapsed, 2.316 minutes remaining
# 7.8 % completed, 0.196 minutes elapsed, 2.311 minutes remaining
# 8.0 % completed, 0.201 minutes elapsed, 2.307 minutes remaining
# 8.2 % completed, 0.206 minutes elapsed, 2.302 minutes remaining
# 8.4 % completed, 0.211 minutes elapsed, 2.297 minutes remaining
# 8.6 % completed, 0.216 minutes elapsed, 2.291 minutes remaining
# 8.8 % completed, 0.221 minutes elapsed, 2.287 minutes remaining
# 9.0 % completed, 0.226 minutes elapsed, 2.282 minutes remaining
# 9.2 % completed, 0.231 minutes elapsed, 2.277 minutes remaining
# 9.4 % completed, 0.236 minutes elapsed, 2.272 minutes remaining
# 9.6 % completed, 0.241 minutes elapsed, 2.266 minutes remaining
# 9.8 % completed, 0.246 minutes elapsed, 2.261 minutes remaining
# 10.0 % completed, 0.251 minutes elapsed, 2.256 minutes remaining
# 10.2 % completed, 0.256 minutes elapsed, 2.252 minutes remaining
# 10.4 % completed, 0.261 minutes elapsed, 2.246 minutes remaining
# 10.6 % completed, 0.266 minutes elapsed, 2.241 minutes remaining
# 10.8 % completed, 0.271 minutes elapsed, 2.237 minutes remaining
# 11.0 % completed, 0.276 minutes elapsed, 2.232 minutes remaining
# 11.2 % completed, 0.281 minutes elapsed, 2.227 minutes remaining
# 11.4 % completed, 0.286 minutes elapsed, 2.222 minutes remaining
# 11.6 % completed, 0.291 minutes elapsed, 2.217 minutes remaining
# 11.8 % completed, 0.297 minutes elapsed, 2.214 minutes remaining
# 12.0 % completed, 0.302 minutes elapsed, 2.209 minutes remaining
# 12.2 % completed, 0.307 minutes elapsed, 2.203 minutes remaining
# 12.4 % completed, 0.312 minutes elapsed, 2.198 minutes remaining
# 12.6 % completed, 0.317 minutes elapsed, 2.195 minutes remaining
# 12.8 % completed, 0.322 minutes elapsed, 2.191 minutes remaining
# 13.0 % completed, 0.327 minutes elapsed, 2.186 minutes remaining
# 13.2 % completed, 0.333 minutes elapsed, 2.183 minutes remaining
# 13.4 % completed, 0.338 minutes elapsed, 2.184 minutes remaining
# 13.6 % completed, 0.344 minutes elapsed, 2.179 minutes remaining
# 13.8 % completed, 0.349 minutes elapsed, 2.175 minutes remaining
# 14.0 % completed, 0.354 minutes elapsed, 2.17 minutes remaining
# 14.2 % completed, 0.359 minutes elapsed, 2.164 minutes remaining
# 14.4 % completed, 0.364 minutes elapsed, 2.161 minutes remaining
# 14.6 % completed, 0.369 minutes elapsed, 2.156 minutes remaining
# 14.8 % completed, 0.374 minutes elapsed, 2.151 minutes remaining
# 15.0 % completed, 0.379 minutes elapsed, 2.145 minutes remaining
# 15.2 % completed, 0.384 minutes elapsed, 2.142 minutes remaining
# 15.4 % completed, 0.39 minutes elapsed, 2.138 minutes remaining
# 15.6 % completed, 0.395 minutes elapsed, 2.133 minutes remaining
# 15.8 % completed, 0.4 minutes elapsed, 2.129 minutes remaining
# 16.0 % completed, 0.405 minutes elapsed, 2.125 minutes remaining
# 16.2 % completed, 0.41 minutes elapsed, 2.12 minutes remaining
# 16.4 % completed, 0.415 minutes elapsed, 2.115 minutes remaining
# 16.6 % completed, 0.421 minutes elapsed, 2.111 minutes remaining
# 16.8 % completed, 0.426 minutes elapsed, 2.106 minutes remaining
# 17.0 % completed, 0.431 minutes elapsed, 2.1 minutes remaining
# 17.2 % completed, 0.436 minutes elapsed, 2.095 minutes remaining
# 17.4 % completed, 0.441 minutes elapsed, 2.09 minutes remaining
# 17.6 % completed, 0.446 minutes elapsed, 2.085 minutes remaining
# 17.8 % completed, 0.451 minutes elapsed, 2.081 minutes remaining
# 18.0 % completed, 0.456 minutes elapsed, 2.076 minutes remaining
# 18.2 % completed, 0.461 minutes elapsed, 2.071 minutes remaining
# 18.4 % completed, 0.466 minutes elapsed, 2.066 minutes remaining
# 18.6 % completed, 0.471 minutes elapsed, 2.061 minutes remaining
# 18.8 % completed, 0.477 minutes elapsed, 2.056 minutes remaining
# 19.0 % completed, 0.482 minutes elapsed, 2.051 minutes remaining
# 19.2 % completed, 0.487 minutes elapsed, 2.046 minutes remaining
# 19.4 % completed, 0.492 minutes elapsed, 2.04 minutes remaining
# 19.6 % completed, 0.497 minutes elapsed, 2.035 minutes remaining
# 19.8 % completed, 0.502 minutes elapsed, 2.03 minutes remaining
# 20.0 % completed, 0.507 minutes elapsed, 2.025 minutes remaining
# 20.2 % completed, 0.512 minutes elapsed, 2.019 minutes remaining
# 20.4 % completed, 0.517 minutes elapsed, 2.014 minutes remaining
# 20.6 % completed, 0.522 minutes elapsed, 2.008 minutes remaining
# 20.8 % completed, 0.527 minutes elapsed, 2.003 minutes remaining
# 21.0 % completed, 0.532 minutes elapsed, 1.998 minutes remaining
# 21.2 % completed, 0.537 minutes elapsed, 1.992 minutes remaining
# 21.4 % completed, 0.542 minutes elapsed, 1.987 minutes remaining
# 21.6 % completed, 0.547 minutes elapsed, 1.982 minutes remaining
# 21.8 % completed, 0.552 minutes elapsed, 1.977 minutes remaining
# 22.0 % completed, 0.557 minutes elapsed, 1.972 minutes remaining
# 22.2 % completed, 0.562 minutes elapsed, 1.966 minutes remaining
# 22.4 % completed, 0.567 minutes elapsed, 1.961 minutes remaining
# 22.6 % completed, 0.572 minutes elapsed, 1.956 minutes remaining
# 22.8 % completed, 0.577 minutes elapsed, 1.951 minutes remaining
# 23.0 % completed, 0.582 minutes elapsed, 1.946 minutes remaining
# 23.2 % completed, 0.587 minutes elapsed, 1.941 minutes remaining
# 23.4 % completed, 0.592 minutes elapsed, 1.935 minutes remaining
# 23.6 % completed, 0.597 minutes elapsed, 1.93 minutes remaining
# 23.8 % completed, 0.602 minutes elapsed, 1.925 minutes remaining
# 24.0 % completed, 0.607 minutes elapsed, 1.919 minutes remaining
# 24.2 % completed, 0.612 minutes elapsed, 1.914 minutes remaining
# 24.4 % completed, 0.617 minutes elapsed, 1.909 minutes remaining
# 24.6 % completed, 0.622 minutes elapsed, 1.904 minutes remaining
# 24.8 % completed, 0.627 minutes elapsed, 1.898 minutes remaining
# 25.0 % completed, 0.632 minutes elapsed, 1.893 minutes remaining
# 25.2 % completed, 0.637 minutes elapsed, 1.888 minutes remaining
# 25.4 % completed, 0.642 minutes elapsed, 1.883 minutes remaining
# 25.6 % completed, 0.646 minutes elapsed, 1.877 minutes remaining
# 25.8 % completed, 0.651 minutes elapsed, 1.872 minutes remaining
# 26.0 % completed, 0.656 minutes elapsed, 1.867 minutes remaining
# 26.2 % completed, 0.661 minutes elapsed, 1.862 minutes remaining
# 26.4 % completed, 0.666 minutes elapsed, 1.857 minutes remaining
# 26.6 % completed, 0.672 minutes elapsed, 1.852 minutes remaining
# 26.8 % completed, 0.676 minutes elapsed, 1.846 minutes remaining
# 27.0 % completed, 0.681 minutes elapsed, 1.841 minutes remaining
# 27.2 % completed, 0.686 minutes elapsed, 1.836 minutes remaining
# 27.4 % completed, 0.691 minutes elapsed, 1.831 minutes remaining
# 27.6 % completed, 0.696 minutes elapsed, 1.826 minutes remaining
# 27.8 % completed, 0.701 minutes elapsed, 1.821 minutes remaining
# 28.0 % completed, 0.706 minutes elapsed, 1.815 minutes remaining
# 28.2 % completed, 0.712 minutes elapsed, 1.81 minutes remaining
# 28.4 % completed, 0.717 minutes elapsed, 1.805 minutes remaining
# 28.6 % completed, 0.721 minutes elapsed, 1.8 minutes remaining
# 28.8 % completed, 0.726 minutes elapsed, 1.795 minutes remaining
# 29.0 % completed, 0.731 minutes elapsed, 1.789 minutes remaining
# 29.2 % completed, 0.736 minutes elapsed, 1.784 minutes remaining
# 29.4 % completed, 0.741 minutes elapsed, 1.779 minutes remaining
# 29.6 % completed, 0.746 minutes elapsed, 1.774 minutes remaining
# 29.8 % completed, 0.751 minutes elapsed, 1.769 minutes remaining
# 30.0 % completed, 0.756 minutes elapsed, 1.764 minutes remaining
# 30.2 % completed, 0.761 minutes elapsed, 1.759 minutes remaining
# 30.4 % completed, 0.767 minutes elapsed, 1.755 minutes remaining
# 30.6 % completed, 0.772 minutes elapsed, 1.751 minutes remaining
# 30.8 % completed, 0.777 minutes elapsed, 1.745 minutes remaining
# 31.0 % completed, 0.782 minutes elapsed, 1.74 minutes remaining
# 31.2 % completed, 0.787 minutes elapsed, 1.735 minutes remaining
# 31.4 % completed, 0.792 minutes elapsed, 1.73 minutes remaining
# 31.6 % completed, 0.797 minutes elapsed, 1.725 minutes remaining
# 31.8 % completed, 0.802 minutes elapsed, 1.72 minutes remaining
# 32.0 % completed, 0.807 minutes elapsed, 1.714 minutes remaining
# 32.2 % completed, 0.812 minutes elapsed, 1.709 minutes remaining
# 32.4 % completed, 0.817 minutes elapsed, 1.704 minutes remaining
# 32.6 % completed, 0.822 minutes elapsed, 1.699 minutes remaining
# 32.8 % completed, 0.827 minutes elapsed, 1.694 minutes remaining
# 33.0 % completed, 0.832 minutes elapsed, 1.689 minutes remaining
# 33.2 % completed, 0.837 minutes elapsed, 1.684 minutes remaining
# 33.4 % completed, 0.842 minutes elapsed, 1.679 minutes remaining
# 33.6 % completed, 0.847 minutes elapsed, 1.673 minutes remaining
# 33.8 % completed, 0.852 minutes elapsed, 1.668 minutes remaining
# 34.0 % completed, 0.857 minutes elapsed, 1.664 minutes remaining
# 34.2 % completed, 0.862 minutes elapsed, 1.658 minutes remaining
# 34.4 % completed, 0.867 minutes elapsed, 1.653 minutes remaining
# 34.6 % completed, 0.873 minutes elapsed, 1.648 minutes remaining
# 34.8 % completed, 0.877 minutes elapsed, 1.643 minutes remaining
# 35.0 % completed, 0.883 minutes elapsed, 1.638 minutes remaining
# 35.2 % completed, 0.888 minutes elapsed, 1.633 minutes remaining
# 35.4 % completed, 0.893 minutes elapsed, 1.628 minutes remaining
# 35.6 % completed, 0.898 minutes elapsed, 1.623 minutes remaining
# 35.8 % completed, 0.903 minutes elapsed, 1.618 minutes remaining
# 36.0 % completed, 0.908 minutes elapsed, 1.613 minutes remaining
# 36.2 % completed, 0.913 minutes elapsed, 1.608 minutes remaining
# 36.4 % completed, 0.918 minutes elapsed, 1.603 minutes remaining
# 36.6 % completed, 0.923 minutes elapsed, 1.598 minutes remaining
# 36.8 % completed, 0.928 minutes elapsed, 1.593 minutes remaining
# 37.0 % completed, 0.933 minutes elapsed, 1.588 minutes remaining
# 37.2 % completed, 0.938 minutes elapsed, 1.583 minutes remaining
# 37.4 % completed, 0.943 minutes elapsed, 1.578 minutes remaining
# 37.6 % completed, 0.948 minutes elapsed, 1.573 minutes remaining
# 37.8 % completed, 0.953 minutes elapsed, 1.568 minutes remaining
# 38.0 % completed, 0.958 minutes elapsed, 1.562 minutes remaining
# 38.2 % completed, 0.963 minutes elapsed, 1.557 minutes remaining
# 38.4 % completed, 0.968 minutes elapsed, 1.552 minutes remaining
# 38.6 % completed, 0.973 minutes elapsed, 1.547 minutes remaining
# 38.8 % completed, 0.978 minutes elapsed, 1.542 minutes remaining
# 39.0 % completed, 0.983 minutes elapsed, 1.537 minutes remaining
# 39.2 % completed, 0.988 minutes elapsed, 1.532 minutes remaining
# 39.4 % completed, 0.993 minutes elapsed, 1.527 minutes remaining
# 39.6 % completed, 0.998 minutes elapsed, 1.521 minutes remaining
# 39.8 % completed, 1.003 minutes elapsed, 1.516 minutes remaining
# 40.0 % completed, 1.008 minutes elapsed, 1.511 minutes remaining
# 40.2 % completed, 1.013 minutes elapsed, 1.506 minutes remaining
# 40.4 % completed, 1.018 minutes elapsed, 1.501 minutes remaining
# 40.6 % completed, 1.023 minutes elapsed, 1.496 minutes remaining
# 40.8 % completed, 1.028 minutes elapsed, 1.491 minutes remaining
# 41.0 % completed, 1.033 minutes elapsed, 1.486 minutes remaining
# 41.2 % completed, 1.038 minutes elapsed, 1.481 minutes remaining
# 41.4 % completed, 1.043 minutes elapsed, 1.476 minutes remaining
# 41.6 % completed, 1.048 minutes elapsed, 1.471 minutes remaining
# 41.8 % completed, 1.054 minutes elapsed, 1.466 minutes remaining
# 42.0 % completed, 1.059 minutes elapsed, 1.461 minutes remaining
# 42.2 % completed, 1.064 minutes elapsed, 1.456 minutes remaining
# 42.4 % completed, 1.069 minutes elapsed, 1.451 minutes remaining
# 42.6 % completed, 1.074 minutes elapsed, 1.446 minutes remaining
# 42.8 % completed, 1.079 minutes elapsed, 1.441 minutes remaining
# 43.0 % completed, 1.084 minutes elapsed, 1.436 minutes remaining
# 43.2 % completed, 1.089 minutes elapsed, 1.431 minutes remaining
# 43.4 % completed, 1.094 minutes elapsed, 1.426 minutes remaining
# 43.6 % completed, 1.099 minutes elapsed, 1.42 minutes remaining
# 43.8 % completed, 1.104 minutes elapsed, 1.416 minutes remaining
# 44.0 % completed, 1.109 minutes elapsed, 1.411 minutes remaining
# 44.2 % completed, 1.115 minutes elapsed, 1.406 minutes remaining
# 44.4 % completed, 1.12 minutes elapsed, 1.402 minutes remaining
# 44.6 % completed, 1.125 minutes elapsed, 1.397 minutes remaining
# 44.8 % completed, 1.13 minutes elapsed, 1.392 minutes remaining
# 45.0 % completed, 1.135 minutes elapsed, 1.387 minutes remaining
# 45.2 % completed, 1.14 minutes elapsed, 1.382 minutes remaining
# 45.4 % completed, 1.145 minutes elapsed, 1.377 minutes remaining
# 45.6 % completed, 1.15 minutes elapsed, 1.372 minutes remaining
# 45.8 % completed, 1.155 minutes elapsed, 1.367 minutes remaining
# 46.0 % completed, 1.16 minutes elapsed, 1.362 minutes remaining
# 46.2 % completed, 1.165 minutes elapsed, 1.356 minutes remaining
# 46.4 % completed, 1.17 minutes elapsed, 1.351 minutes remaining
# 46.6 % completed, 1.175 minutes elapsed, 1.346 minutes remaining
# 46.8 % completed, 1.18 minutes elapsed, 1.341 minutes remaining
# 47.0 % completed, 1.185 minutes elapsed, 1.336 minutes remaining
# 47.2 % completed, 1.19 minutes elapsed, 1.331 minutes remaining
# 47.4 % completed, 1.195 minutes elapsed, 1.326 minutes remaining
# 47.6 % completed, 1.201 minutes elapsed, 1.322 minutes remaining
# 47.8 % completed, 1.206 minutes elapsed, 1.317 minutes remaining
# 48.0 % completed, 1.211 minutes elapsed, 1.312 minutes remaining
# 48.2 % completed, 1.216 minutes elapsed, 1.307 minutes remaining
# 48.4 % completed, 1.222 minutes elapsed, 1.302 minutes remaining
# 48.6 % completed, 1.227 minutes elapsed, 1.297 minutes remaining
# 48.8 % completed, 1.232 minutes elapsed, 1.292 minutes remaining
# 49.0 % completed, 1.237 minutes elapsed, 1.287 minutes remaining
# 49.2 % completed, 1.242 minutes elapsed, 1.282 minutes remaining
# 49.4 % completed, 1.247 minutes elapsed, 1.277 minutes remaining
# 49.6 % completed, 1.252 minutes elapsed, 1.272 minutes remaining
# 49.8 % completed, 1.257 minutes elapsed, 1.267 minutes remaining
# 50.0 % completed, 1.262 minutes elapsed, 1.262 minutes remaining
# 50.2 % completed, 1.267 minutes elapsed, 1.257 minutes remaining
# 50.4 % completed, 1.272 minutes elapsed, 1.251 minutes remaining
# 50.6 % completed, 1.277 minutes elapsed, 1.247 minutes remaining
# 50.8 % completed, 1.282 minutes elapsed, 1.242 minutes remaining
# 51.0 % completed, 1.287 minutes elapsed, 1.236 minutes remaining
# 51.2 % completed, 1.292 minutes elapsed, 1.231 minutes remaining
# 51.4 % completed, 1.297 minutes elapsed, 1.226 minutes remaining
# 51.6 % completed, 1.302 minutes elapsed, 1.221 minutes remaining
# 51.8 % completed, 1.307 minutes elapsed, 1.216 minutes remaining
# 52.0 % completed, 1.312 minutes elapsed, 1.211 minutes remaining
# 52.2 % completed, 1.317 minutes elapsed, 1.206 minutes remaining
# 52.4 % completed, 1.322 minutes elapsed, 1.201 minutes remaining
# 52.6 % completed, 1.327 minutes elapsed, 1.196 minutes remaining
# 52.8 % completed, 1.332 minutes elapsed, 1.191 minutes remaining
# 53.0 % completed, 1.337 minutes elapsed, 1.185 minutes remaining
# 53.2 % completed, 1.342 minutes elapsed, 1.18 minutes remaining
# 53.4 % completed, 1.347 minutes elapsed, 1.175 minutes remaining
# 53.6 % completed, 1.353 minutes elapsed, 1.17 minutes remaining
# 53.8 % completed, 1.358 minutes elapsed, 1.165 minutes remaining
# 54.0 % completed, 1.363 minutes elapsed, 1.16 minutes remaining
# 54.2 % completed, 1.368 minutes elapsed, 1.155 minutes remaining
# 54.4 % completed, 1.372 minutes elapsed, 1.15 minutes remaining
# 54.6 % completed, 1.377 minutes elapsed, 1.145 minutes remaining
# 54.8 % completed, 1.382 minutes elapsed, 1.14 minutes remaining
# 55.0 % completed, 1.388 minutes elapsed, 1.135 minutes remaining
# 55.2 % completed, 1.393 minutes elapsed, 1.13 minutes remaining
# 55.4 % completed, 1.398 minutes elapsed, 1.125 minutes remaining
# 55.6 % completed, 1.403 minutes elapsed, 1.12 minutes remaining
# 55.8 % completed, 1.408 minutes elapsed, 1.115 minutes remaining
# 56.0 % completed, 1.413 minutes elapsed, 1.11 minutes remaining
# 56.2 % completed, 1.418 minutes elapsed, 1.105 minutes remaining
# 56.4 % completed, 1.423 minutes elapsed, 1.1 minutes remaining
# 56.6 % completed, 1.428 minutes elapsed, 1.095 minutes remaining
# 56.8 % completed, 1.433 minutes elapsed, 1.09 minutes remaining
# 57.0 % completed, 1.438 minutes elapsed, 1.085 minutes remaining
# 57.2 % completed, 1.443 minutes elapsed, 1.08 minutes remaining
# 57.4 % completed, 1.449 minutes elapsed, 1.075 minutes remaining
# 57.6 % completed, 1.454 minutes elapsed, 1.07 minutes remaining
# 57.8 % completed, 1.459 minutes elapsed, 1.065 minutes remaining
# 58.0 % completed, 1.464 minutes elapsed, 1.06 minutes remaining
# 58.2 % completed, 1.469 minutes elapsed, 1.055 minutes remaining
# 58.4 % completed, 1.474 minutes elapsed, 1.05 minutes remaining
# 58.6 % completed, 1.48 minutes elapsed, 1.045 minutes remaining
# 58.8 % completed, 1.485 minutes elapsed, 1.04 minutes remaining
# 59.0 % completed, 1.49 minutes elapsed, 1.035 minutes remaining
# 59.2 % completed, 1.495 minutes elapsed, 1.03 minutes remaining
# 59.4 % completed, 1.5 minutes elapsed, 1.025 minutes remaining
# 59.6 % completed, 1.505 minutes elapsed, 1.02 minutes remaining
# 59.8 % completed, 1.51 minutes elapsed, 1.015 minutes remaining
# 60.0 % completed, 1.515 minutes elapsed, 1.009 minutes remaining
# 60.2 % completed, 1.52 minutes elapsed, 1.004 minutes remaining
# 60.4 % completed, 1.525 minutes elapsed, 0.999 minutes remaining
# 60.6 % completed, 1.53 minutes elapsed, 0.994 minutes remaining
# 60.8 % completed, 1.535 minutes elapsed, 0.989 minutes remaining
# 61.0 % completed, 1.54 minutes elapsed, 0.984 minutes remaining
# 61.2 % completed, 1.545 minutes elapsed, 0.979 minutes remaining
# 61.4 % completed, 1.55 minutes elapsed, 0.974 minutes remaining
# 61.6 % completed, 1.555 minutes elapsed, 0.969 minutes remaining
# 61.8 % completed, 1.562 minutes elapsed, 0.965 minutes remaining
# 62.0 % completed, 1.569 minutes elapsed, 0.961 minutes remaining
# 62.2 % completed, 1.574 minutes elapsed, 0.956 minutes remaining
# 62.4 % completed, 1.579 minutes elapsed, 0.951 minutes remaining
# 62.6 % completed, 1.584 minutes elapsed, 0.946 minutes remaining
# 62.8 % completed, 1.59 minutes elapsed, 0.941 minutes remaining
# 63.0 % completed, 1.595 minutes elapsed, 0.936 minutes remaining
# 63.2 % completed, 1.6 minutes elapsed, 0.931 minutes remaining
# 63.4 % completed, 1.605 minutes elapsed, 0.926 minutes remaining
# 63.6 % completed, 1.61 minutes elapsed, 0.921 minutes remaining
# 63.8 % completed, 1.615 minutes elapsed, 0.916 minutes remaining
# 64.0 % completed, 1.62 minutes elapsed, 0.911 minutes remaining
# 64.2 % completed, 1.625 minutes elapsed, 0.906 minutes remaining
# 64.4 % completed, 1.63 minutes elapsed, 0.901 minutes remaining
# 64.6 % completed, 1.636 minutes elapsed, 0.896 minutes remaining
# 64.8 % completed, 1.641 minutes elapsed, 0.891 minutes remaining
# 65.0 % completed, 1.646 minutes elapsed, 0.886 minutes remaining
# 65.2 % completed, 1.651 minutes elapsed, 0.881 minutes remaining
# 65.4 % completed, 1.657 minutes elapsed, 0.876 minutes remaining
# 65.6 % completed, 1.662 minutes elapsed, 0.871 minutes remaining
# 65.8 % completed, 1.667 minutes elapsed, 0.866 minutes remaining
# 66.0 % completed, 1.672 minutes elapsed, 0.861 minutes remaining
# 66.2 % completed, 1.677 minutes elapsed, 0.856 minutes remaining
# 66.4 % completed, 1.682 minutes elapsed, 0.851 minutes remaining
# 66.6 % completed, 1.688 minutes elapsed, 0.846 minutes remaining
# 66.8 % completed, 1.693 minutes elapsed, 0.841 minutes remaining
# 67.0 % completed, 1.698 minutes elapsed, 0.836 minutes remaining
# 67.2 % completed, 1.703 minutes elapsed, 0.831 minutes remaining
# 67.4 % completed, 1.708 minutes elapsed, 0.826 minutes remaining
# 67.6 % completed, 1.713 minutes elapsed, 0.821 minutes remaining
# 67.8 % completed, 1.718 minutes elapsed, 0.816 minutes remaining
# 68.0 % completed, 1.723 minutes elapsed, 0.811 minutes remaining
# 68.2 % completed, 1.728 minutes elapsed, 0.805 minutes remaining
# 68.4 % completed, 1.733 minutes elapsed, 0.8 minutes remaining
# 68.6 % completed, 1.738 minutes elapsed, 0.795 minutes remaining
# 68.8 % completed, 1.743 minutes elapsed, 0.79 minutes remaining
# 69.0 % completed, 1.748 minutes elapsed, 0.785 minutes remaining
# 69.2 % completed, 1.754 minutes elapsed, 0.78 minutes remaining
# 69.4 % completed, 1.759 minutes elapsed, 0.775 minutes remaining
# 69.6 % completed, 1.764 minutes elapsed, 0.77 minutes remaining
# 69.8 % completed, 1.769 minutes elapsed, 0.765 minutes remaining
# 70.0 % completed, 1.774 minutes elapsed, 0.76 minutes remaining
# 70.2 % completed, 1.779 minutes elapsed, 0.755 minutes remaining
# 70.4 % completed, 1.784 minutes elapsed, 0.75 minutes remaining
# 70.6 % completed, 1.789 minutes elapsed, 0.745 minutes remaining
# 70.8 % completed, 1.794 minutes elapsed, 0.74 minutes remaining
# 71.0 % completed, 1.799 minutes elapsed, 0.735 minutes remaining
# 71.2 % completed, 1.804 minutes elapsed, 0.73 minutes remaining
# 71.4 % completed, 1.809 minutes elapsed, 0.725 minutes remaining
# 71.6 % completed, 1.814 minutes elapsed, 0.719 minutes remaining
# 71.8 % completed, 1.819 minutes elapsed, 0.714 minutes remaining
# 72.0 % completed, 1.824 minutes elapsed, 0.709 minutes remaining
# 72.2 % completed, 1.83 minutes elapsed, 0.704 minutes remaining
# 72.4 % completed, 1.835 minutes elapsed, 0.699 minutes remaining
# 72.6 % completed, 1.84 minutes elapsed, 0.694 minutes remaining
# 72.8 % completed, 1.845 minutes elapsed, 0.689 minutes remaining
# 73.0 % completed, 1.85 minutes elapsed, 0.684 minutes remaining
# 73.2 % completed, 1.855 minutes elapsed, 0.679 minutes remaining
# 73.4 % completed, 1.86 minutes elapsed, 0.674 minutes remaining
# 73.6 % completed, 1.866 minutes elapsed, 0.669 minutes remaining
# 73.8 % completed, 1.871 minutes elapsed, 0.664 minutes remaining
# 74.0 % completed, 1.877 minutes elapsed, 0.659 minutes remaining
# 74.2 % completed, 1.885 minutes elapsed, 0.655 minutes remaining
# 74.4 % completed, 1.89 minutes elapsed, 0.65 minutes remaining
# 74.6 % completed, 1.896 minutes elapsed, 0.645 minutes remaining
# 74.8 % completed, 1.901 minutes elapsed, 0.64 minutes remaining
# 75.0 % completed, 1.906 minutes elapsed, 0.635 minutes remaining
# 75.2 % completed, 1.912 minutes elapsed, 0.63 minutes remaining
# 75.4 % completed, 1.917 minutes elapsed, 0.625 minutes remaining
# 75.6 % completed, 1.922 minutes elapsed, 0.62 minutes remaining
# 75.8 % completed, 1.927 minutes elapsed, 0.615 minutes remaining
# 76.0 % completed, 1.933 minutes elapsed, 0.61 minutes remaining
# 76.2 % completed, 1.938 minutes elapsed, 0.605 minutes remaining
# 76.4 % completed, 1.943 minutes elapsed, 0.6 minutes remaining
# 76.6 % completed, 1.948 minutes elapsed, 0.595 minutes remaining
# 76.8 % completed, 1.954 minutes elapsed, 0.59 minutes remaining
# 77.0 % completed, 1.959 minutes elapsed, 0.585 minutes remaining
# 77.2 % completed, 1.964 minutes elapsed, 0.58 minutes remaining
# 77.4 % completed, 1.97 minutes elapsed, 0.575 minutes remaining
# 77.6 % completed, 1.975 minutes elapsed, 0.57 minutes remaining
# 77.8 % completed, 1.98 minutes elapsed, 0.565 minutes remaining
# 78.0 % completed, 1.985 minutes elapsed, 0.56 minutes remaining
# 78.2 % completed, 1.991 minutes elapsed, 0.555 minutes remaining
# 78.4 % completed, 1.996 minutes elapsed, 0.55 minutes remaining
# 78.6 % completed, 2.001 minutes elapsed, 0.545 minutes remaining
# 78.8 % completed, 2.006 minutes elapsed, 0.54 minutes remaining
# 79.0 % completed, 2.011 minutes elapsed, 0.535 minutes remaining
# 79.2 % completed, 2.017 minutes elapsed, 0.53 minutes remaining
# 79.4 % completed, 2.022 minutes elapsed, 0.524 minutes remaining
# 79.6 % completed, 2.027 minutes elapsed, 0.519 minutes remaining
# 79.8 % completed, 2.033 minutes elapsed, 0.514 minutes remaining
# 80.0 % completed, 2.038 minutes elapsed, 0.509 minutes remaining
# 80.2 % completed, 2.043 minutes elapsed, 0.504 minutes remaining
# 80.4 % completed, 2.048 minutes elapsed, 0.499 minutes remaining
# 80.6 % completed, 2.054 minutes elapsed, 0.494 minutes remaining
# 80.8 % completed, 2.059 minutes elapsed, 0.489 minutes remaining
# 81.0 % completed, 2.064 minutes elapsed, 0.484 minutes remaining
# 81.2 % completed, 2.071 minutes elapsed, 0.479 minutes remaining
# 81.4 % completed, 2.076 minutes elapsed, 0.474 minutes remaining
# 81.6 % completed, 2.081 minutes elapsed, 0.469 minutes remaining
# 81.8 % completed, 2.086 minutes elapsed, 0.464 minutes remaining
# 82.0 % completed, 2.092 minutes elapsed, 0.459 minutes remaining
# 82.2 % completed, 2.097 minutes elapsed, 0.454 minutes remaining
# 82.4 % completed, 2.102 minutes elapsed, 0.449 minutes remaining
# 82.6 % completed, 2.107 minutes elapsed, 0.444 minutes remaining
# 82.8 % completed, 2.112 minutes elapsed, 0.439 minutes remaining
# 83.0 % completed, 2.118 minutes elapsed, 0.434 minutes remaining
# 83.2 % completed, 2.123 minutes elapsed, 0.429 minutes remaining
# 83.4 % completed, 2.128 minutes elapsed, 0.424 minutes remaining
# 83.6 % completed, 2.133 minutes elapsed, 0.418 minutes remaining
# 83.8 % completed, 2.139 minutes elapsed, 0.413 minutes remaining
# 84.0 % completed, 2.144 minutes elapsed, 0.408 minutes remaining
# 84.2 % completed, 2.149 minutes elapsed, 0.403 minutes remaining
# 84.4 % completed, 2.154 minutes elapsed, 0.398 minutes remaining
# 84.6 % completed, 2.16 minutes elapsed, 0.393 minutes remaining
# 84.8 % completed, 2.165 minutes elapsed, 0.388 minutes remaining
# 85.0 % completed, 2.17 minutes elapsed, 0.383 minutes remaining
# 85.2 % completed, 2.175 minutes elapsed, 0.378 minutes remaining
# 85.4 % completed, 2.18 minutes elapsed, 0.373 minutes remaining
# 85.6 % completed, 2.186 minutes elapsed, 0.368 minutes remaining
# 85.8 % completed, 2.191 minutes elapsed, 0.363 minutes remaining
# 86.0 % completed, 2.196 minutes elapsed, 0.357 minutes remaining
# 86.2 % completed, 2.201 minutes elapsed, 0.352 minutes remaining
# 86.4 % completed, 2.207 minutes elapsed, 0.347 minutes remaining
# 86.6 % completed, 2.212 minutes elapsed, 0.342 minutes remaining
# 86.8 % completed, 2.217 minutes elapsed, 0.337 minutes remaining
# 87.0 % completed, 2.222 minutes elapsed, 0.332 minutes remaining
# 87.2 % completed, 2.228 minutes elapsed, 0.327 minutes remaining
# 87.4 % completed, 2.233 minutes elapsed, 0.322 minutes remaining
# 87.6 % completed, 2.238 minutes elapsed, 0.317 minutes remaining
# 87.8 % completed, 2.243 minutes elapsed, 0.312 minutes remaining
# 88.0 % completed, 2.249 minutes elapsed, 0.307 minutes remaining
# 88.2 % completed, 2.254 minutes elapsed, 0.301 minutes remaining
# 88.4 % completed, 2.259 minutes elapsed, 0.296 minutes remaining
# 88.6 % completed, 2.264 minutes elapsed, 0.291 minutes remaining
# 88.8 % completed, 2.269 minutes elapsed, 0.286 minutes remaining
# 89.0 % completed, 2.274 minutes elapsed, 0.281 minutes remaining
# 89.2 % completed, 2.279 minutes elapsed, 0.276 minutes remaining
# 89.4 % completed, 2.285 minutes elapsed, 0.271 minutes remaining
# 89.6 % completed, 2.29 minutes elapsed, 0.266 minutes remaining
# 89.8 % completed, 2.295 minutes elapsed, 0.261 minutes remaining
# 90.0 % completed, 2.3 minutes elapsed, 0.255 minutes remaining
# 90.2 % completed, 2.305 minutes elapsed, 0.25 minutes remaining
# 90.4 % completed, 2.31 minutes elapsed, 0.245 minutes remaining
# 90.6 % completed, 2.315 minutes elapsed, 0.24 minutes remaining
# 90.8 % completed, 2.32 minutes elapsed, 0.235 minutes remaining
# 91.0 % completed, 2.325 minutes elapsed, 0.23 minutes remaining
# 91.2 % completed, 2.33 minutes elapsed, 0.225 minutes remaining
# 91.4 % completed, 2.335 minutes elapsed, 0.22 minutes remaining
# 91.6 % completed, 2.341 minutes elapsed, 0.215 minutes remaining
# 91.8 % completed, 2.346 minutes elapsed, 0.21 minutes remaining
# 92.0 % completed, 2.351 minutes elapsed, 0.204 minutes remaining
# 92.2 % completed, 2.356 minutes elapsed, 0.199 minutes remaining
# 92.4 % completed, 2.361 minutes elapsed, 0.194 minutes remaining
# 92.6 % completed, 2.366 minutes elapsed, 0.189 minutes remaining
# 92.8 % completed, 2.371 minutes elapsed, 0.184 minutes remaining
# 93.0 % completed, 2.377 minutes elapsed, 0.179 minutes remaining
# 93.2 % completed, 2.382 minutes elapsed, 0.174 minutes remaining
# 93.4 % completed, 2.387 minutes elapsed, 0.169 minutes remaining
# 93.6 % completed, 2.392 minutes elapsed, 0.164 minutes remaining
# 93.8 % completed, 2.397 minutes elapsed, 0.158 minutes remaining
# 94.0 % completed, 2.402 minutes elapsed, 0.153 minutes remaining
# 94.2 % completed, 2.407 minutes elapsed, 0.148 minutes remaining
# 94.4 % completed, 2.412 minutes elapsed, 0.143 minutes remaining
# 94.6 % completed, 2.417 minutes elapsed, 0.138 minutes remaining
# 94.8 % completed, 2.422 minutes elapsed, 0.133 minutes remaining
# 95.0 % completed, 2.427 minutes elapsed, 0.128 minutes remaining
# 95.2 % completed, 2.432 minutes elapsed, 0.123 minutes remaining
# 95.4 % completed, 2.438 minutes elapsed, 0.118 minutes remaining
# 95.6 % completed, 2.443 minutes elapsed, 0.112 minutes remaining
# 95.8 % completed, 2.448 minutes elapsed, 0.107 minutes remaining
# 96.0 % completed, 2.453 minutes elapsed, 0.102 minutes remaining
# 96.2 % completed, 2.458 minutes elapsed, 0.097 minutes remaining
# 96.4 % completed, 2.463 minutes elapsed, 0.092 minutes remaining
# 96.6 % completed, 2.468 minutes elapsed, 0.087 minutes remaining
# 96.8 % completed, 2.473 minutes elapsed, 0.082 minutes remaining
# 97.0 % completed, 2.478 minutes elapsed, 0.077 minutes remaining
# 97.2 % completed, 2.483 minutes elapsed, 0.072 minutes remaining
# 97.4 % completed, 2.488 minutes elapsed, 0.066 minutes remaining
# 97.6 % completed, 2.494 minutes elapsed, 0.061 minutes remaining
# 97.8 % completed, 2.499 minutes elapsed, 0.056 minutes remaining
# 98.0 % completed, 2.505 minutes elapsed, 0.051 minutes remaining
# 98.2 % completed, 2.51 minutes elapsed, 0.046 minutes remaining
# 98.4 % completed, 2.515 minutes elapsed, 0.041 minutes remaining
# 98.6 % completed, 2.52 minutes elapsed, 0.036 minutes remaining
# 98.8 % completed, 2.525 minutes elapsed, 0.031 minutes remaining
# 99.0 % completed, 2.53 minutes elapsed, 0.026 minutes remaining
# 99.2 % completed, 2.535 minutes elapsed, 0.02 minutes remaining
# 99.4 % completed, 2.54 minutes elapsed, 0.015 minutes remaining
# 99.6 % completed, 2.545 minutes elapsed, 0.01 minutes remaining
# 99.8 % completed, 2.55 minutes elapsed, 0.005 minutes remaining
# Finished bootstrapping!

# %%
print(mix_coeffs_all)
# Out:
# [array([[0.18985162, 0.81014838],
#        [0.42725352, 0.57274648],
#        [0.21225311, 0.78774689],
#        ...,
#        [0.08895544, 0.91104456],
#        [0.2306851 , 0.7693149 ],
#        [0.25597769, 0.74402231]])]

# %%
print(f"Number of items: {len(mix_coeffs_all[0])}")
print(f"Array shape: {mix_coeffs_all[0].shape}")
# Out:
# Number of items: 5000
# Array shape: (5000, 2)

# %% [markdown]
# ### Export csv file of mix_coeffs_all for use in the zircon fertility analysis

# %%
# Converting the mix_coeffs_all to a 2D array so that we can run all 5000 pairs of w1 and w2 through to understand the
# distribution through the bootstraping analyses. 

import numpy as np
import pandas as pd
import os

# Convert list to NumPy array
array = np.array(mix_coeffs_all)

# Flatten the array
flattened_array = array.reshape(-1, array.shape[-1])

# Convert to DataFrame
df = pd.DataFrame(flattened_array, columns=['Column1', 'Column2'])

# Save to CSV in a "Spreadsheets" folder
folder_path = "Spreadsheets"
filename = "mix_coeffs_all_ct-5_ct-6_to_ct-4.csv"

# Create folder if it doesn't exist
os.makedirs(folder_path, exist_ok=True)

# Create full path and save
full_path = os.path.join(folder_path, filename)
df.to_csv(full_path, index=False)

# %%
# Plots a histogram of both coeffs as dif colors

flat_array = np.concatenate(mix_coeffs_all)

# Plot histogram with different colors for each pair of components
colors = ['blue', 'orange']  # Colors for each pair of components
n = len(flat_array)
plt.hist(flat_array, bins=50, alpha=0.7, label=['w2', 'w1'], histtype='barstacked')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Mix Coefficients')
plt.legend()
plt.grid(True)
plt.text(0.5, 0.95, f'n = {n}', horizontalalignment='center', verticalalignment='center', transform=plt.gca().transAxes)
plt.show()

print("n =", len(flat_array))
# Out:
# n = 5000

# %% [markdown]
# ### Plot the results of mixture modeling as both cumulative and relative probability distributions
# The code below plots the parents and children along with the best-fit or average mixture. Setting plotMixResults = True also shows mixing results as a line or violin plot (not recommended when using a large number of parents)

# %%
plotType = 'PDP' # Specify the type of plot to make: options are 'KDE' or 'PDP'

fillParent = True # Color parents according to their specified color
parent_colors = 'Default' # 'Default' or specify colors as a list (e.g., ['gray','orange','red'])
child_colors = 'Default' # 'Default' or specify colors as a list or as a single color (e.g., 'gray')

color_by_age = False # Will color KDE or PDP according to age categories if set to True
agebins = [0, 20, 100, 200] # Specify  age categories for colored KDE or PDP (only used if color_by_age = True)
agebinsc = ['red','orange','green']
agebinsc_alpha = 0.5

xaxis_1 = 0 # Minimum x-axis value of plot
xaxis_2 = 400 # Maximum x-axis value of plot

# Specify the plot dimensions
w1 = 8 # width of the KDE or PDP plots
w2 = 4 # width of the mixture modeling plots
c = 4 # height of the CDF panel

# What value should we plot for each mixture? Options: 'best-fit', 'average', 'median'
best_plot_type = 'best-fit'

plotPie = True # Will plot a pie diagram of best-fit, median, or average mixture (specified with 'best_plot_type')

# Specify whether to plot the mixture results (not recommended if using a large number (>>10) of parents)
plotMixResults = True 

plotResultType = 'violin' # Options: 'line' or 'violin'
violin_width = 0.2

fig = dMix.plotMix(main_byid_df, parent_list, child_list, plotType=plotType, bw=bw, bw_x=bw_x, x1=x1, x2=x2, xdif=xdif,
                   fillParent = fillParent, parent_colors=parent_colors, child_colors=child_colors,
                   color_by_age=color_by_age, agebins=agebins, agebinsc=agebinsc, agebinsc_alpha=agebinsc_alpha,
                   xaxis_1=xaxis_1, xaxis_2=xaxis_2, w1=w1, w2=w2, c=c, plotPie=plotPie, plotMixResults=plotMixResults,
                   best_plot_type=best_plot_type, plotResultType=plotResultType, violin_width=violin_width, sigma=sigma,
                  mix_coeffs_all=mix_coeffs_all, mix_coeffs_bf=mix_coeffs_bf, obj_func_val=obj_func_val, best_mixed_dist=best_mixed_dist,
                  obj_vals_all=obj_vals_all, objective_metric=objective_metric)

# %% [markdown]
# <b>Recommended exercise:</b> Try making best_fit_plot equal to 'average' or 'median'

# %%
# Save figure as PDF
fig.savefig('dPy-mix_CT-4_age_distribution.pdf')

# %% [markdown]
# ### Visualize the distribution of mixing results
#
# detritalPy-Mix also contains some functions that allow you to visualize the distributions of model results obtained by bootstrapping.

# %% [markdown]
# **Assess how modelled objective functions compare to those produced by random sampling**
#
# This plot compares the distribution of objective functions calculated by the bootstrapped mixture models with the distribution of objective functions calculated by comparing a child sample to a resampled version of itself.  If the mixture modelling does a good job reproducing the observed child sample, then these distributions should have a large amount of overlap.

# %%
#Default to None to uses black. Otherwise specify a list of colors for each child, e.g., ['dodgerblue', 'mediumseagreen']
# or a single color for all models, e.g., 'dodgerblue'
modelled_colors = None

#Default to None to use default color pallette from detritalPy, 
# otherwise specify a list of colors for each child, e.g., ['dodgerblue', 'mediumseagreen']
# or a single color for all models, e.g., 'dodgerblue'
self_compared_colors = None

#Adds a title with summary statistics to each plot
doAddSummaryTitle = True

#Set up the axis to plot on
plotWidth = 5.0 #How wide should plots be?
subplotHeight = 3.0 #About how tall should each subplot be?

# Create the figure for plotting
f,axs = plt.subplots(len(selfCompMetrics_bs_set),1,figsize = (plotWidth,subplotHeight*len(child_list)),sharex = True);

#Plot the distributions of objective function values
axs = dMix.plot_many_bootstrapped_metric_comparisons_model_observations(obj_vals_all,
                                                                  selfCompMetrics_bs_set, objective_metric,child_list,
                                                                        main_byid_df,
                                                                        obj_func_crit, worse_than_crit,
                                                                        obj_func_val,
                                                                        modelled_colors = modelled_colors,
                                                                        self_compared_colors = self_compared_colors,
                                                                        axs = axs, plotWidth = plotWidth, subplotHeight = subplotHeight,
                                                                        doAddSummaryTitle=doAddSummaryTitle,
                                                                        alpha = 0.5, bins = 50)

# %% [markdown]
# <b>Note:</b> Ideally, the bootstrapped models and bootstrapped self-comparisons will overlap in a 'good' mixture model. The 'crit' objective metric value is equal to the 95th percentile of the bootstrapped self-comparisons. In the synthetic example (Example 1), we expect the model fits to be about as good as the resampled mixture - so the histograms should have quite a bit of overlap.

# %%
#Save figure as PDF
f.savefig('dPy-mix_objective_function_distributions.pdf')

# %% [markdown]
# **Assess how modelled distributions compare to the observed distribution**
#
# This plot compares the range of distributions calculated by the bootstrapped mixture models with the observed distributions. If the mixture modelling does a good job reproducing the observed child sample, then these distributions should look similar.

# %%
xaxis_1 = 0 # Minimum x-axis value of plot
xaxis_2 = 400 # Maximum x-axis value of plot

#Set up the axis to plot on
plotWidth = 6.0 #How wide should plots be?
subplotHeight = 4.0 #About how tall should each subplot be?

#What interval of bootsrapped estimates do you want to summarize?
confidence_interval = 95.0 

#Get some colors for the children
child_colors = 'Default' # Options: 'Default', a list of colors (e.g., ['black','red'], or a single color (e.g., 'black')

#What color do we want to plot model results as?
model_color = 'black'

#How transparent should filled in bounds be?
fill_alpha = 0.25

#Do we want to plot the range of distributions observed in the self-comparison?
plot_self_comparisons = True

#Create the axes to plot on
f,axs = plt.subplots(len(child_list),1,figsize = (plotWidth,subplotHeight*len(child_list)),sharex = True,sharey = 'col')

#Plot
axs = dMix.plot_child_bootstrappedmodel_distribution_comparison(main_byid_df,
                                                                child_modelled_distributions,
                                                                child_list,
                                                                xaxis_1 = xaxis_1, xaxis_2 = xaxis_2,
                                                                x1 = x1, x2 = x2, xdif = xdif, bw = bw, bw_x=bw_x,
                                                                objective_metric = objective_metric,
                                                                confidence_interval = confidence_interval,
                                                                fill_alpha = fill_alpha,
                                                            plot_self_comparisons = plot_self_comparisons,
                                                                childDists_bs_set = childDists_bs_set,
                                                            axs = axs, plotWidth = plotWidth, subplotHeight = subplotHeight,child_colors = child_colors,
                                                                model_color = model_color,sigma = sigma)

# %% [markdown]
# <b>Note:</b> In the synthetic example (Example 1), the observed variability in the Mixture should be pretty similar to the variability in the Model results. In the real-world Example 2, we see that the model uncertainty mostly overlaps with the Loess sample. There is some divergence in the youngest part of the U-Pb age distribution (<~250 Ma). In Example 3, te quality of the mixture modeling is not particularly good and gets progressively worse for older units. Perhaps our choice of parents is not capturing the true sediment sources to the Bengal Fan going back in time?

# %%
#Save figure as PDF
f.savefig('dPy-mix_distribution_comparisons.pdf')

# %% [markdown]
# **Assess how mixture coefficients vary in a section (or spatially)**
#
# We can plot how mixing coefficients vary with some other dimension by plotting summaries of the bootstrapped mixing coefficients against another variable; for example height in a strat column or distance along a transport system.

# %%
separate_parents = True # Set to True to plot each parent in a separate subplot. Set to False to plot all results together in the same plot.

# Define the extra dimension (e.g., spatial or temporal value) for plotting each child
# Note: there needs to be a value in this array for each child
yAxisValues = None #np.array([0.5, 100, 300, 600]) #Set to None to just use evenly spaced values

# Should we flip the x and y axis of the plot, such that the extra dimension (called yAxisValues above)
# is plotted on the horizontal axis?
doFlipXY = False

# Should we add 'error bars' to each point?
do_plot_errorbars = True

# What percentage of mixing coefficients should we summarize?
confidence_interval = 95

# What value should we plot for each mixture? Options: 'best-fit', 'average', 'median'
best_plot_type = 'best-fit'

# Speicy the color of parents
parent_colors = 'Default' # Options: 'Default', a list of colors (e.g., ['black','red'], or a single color (e.g., 'black')
plot_alpha = 0.3 # Plotting transparency

plotWidth = 15.0
plotHeight = 4.0

#Make the plot
f, ax = dMix.plot_bootstrapped_mixturecoefficients_stratigraphy(parent_list, child_list, mix_coeffs_bf, mix_coeffs_all,
                                                            confidence_interval = confidence_interval,
                                                            ax = None, plotWidth = plotWidth,
                                                             plotHeight = plotHeight, parent_colors = parent_colors, 
                                                             do_plot_errorbars = do_plot_errorbars,
                                                            yAxisValues = yAxisValues, doFlipXY = doFlipXY, plot_alpha = plot_alpha,
                                                               separate_parents = separate_parents, best_plot_type = best_plot_type);

# %% [markdown]
# <b>Note:</b> If you are only plotting one child sample (e.g., Examples 1 and 2), this plot is not very interesting. Example 3 provides a better example of how this plot could be used.

# %%
#Save figure as PDF
f.savefig('dPy-mix_spatial_comparison.pdf')

# %% [markdown]
# ### Export results as an Excel file

# %% [markdown]
# Results can be exported as an Excel file with multiple worksheets

# %%
file_name = 'dPy-mix_results.xlsx'

dMix.export_results(parent_list, child_list, main_byid_df, objective_metric, xdif, bw, mix_coeffs_bf, 
                    obj_func_val, file_name=file_name, verbose=True, version=detritalpy.__version__,
                    bootstrap=True, nBootstrapIterations=nBootstrapIterations,
                    doPerturbResampledAges=doPerturbResampledAges,nGrainsToResample=nGrainsToResample,
                    mix_coeffs_all=mix_coeffs_all,obj_vals_all=obj_vals_all, obj_func_crit=obj_func_crit,
                    worse_than_crit=worse_than_crit, selfCompMetrics_bs_set=selfCompMetrics_bs_set)
